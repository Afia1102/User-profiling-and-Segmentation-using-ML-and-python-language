# %% [markdown]
# ##                                           User profiling and Segmentation

# %% [markdown]
# #### Q.1: Import data and check null values, column info, and descriptive statistics of the data.

# %%
import pandas as pd
import numpy as np

# %%
data=pd.read_csv('user_profiles_for_ads.csv')
df=pd.DataFrame(data)

# %%
data.head(5)
# Out:
#    User ID    Age  Gender  Location Language Education Level  \
# 0        1  25-34  Female  Suburban    Hindi       Technical
# 1        2    65+    Male     Urban    Hindi             PhD
# 2        3  45-54  Female  Suburban  Spanish       Technical
# 3        4  35-44  Female     Rural  Spanish             PhD
# 4        5  25-34  Female     Urban  English       Technical
#
#    Likes and Reactions  Followed Accounts  Device Usage  \
# 0                 5640                190   Mobile Only
# 1                 9501                375        Tablet
# 2                 4775                187   Mobile Only
# 3                 9182                152  Desktop Only
# 4                 6848                371   Mobile Only
#
#    Time Spent Online (hrs/weekday)  Time Spent Online (hrs/weekend)  \
# 0                              4.5                              1.7
# 1                              0.5                              7.7
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 16 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   User ID                          1000 non-null   int64
#  1   Age                              1000 non-null   object
#  2   Gender                           1000 non-null   object
#  3   Location                         1000 non-null   object
#  4   Language                         1000 non-null   object
#  5   Education Level                  1000 non-null   object
#  6   Likes and Reactions              1000 non-null   int64
#  7   Followed Accounts                1000 non-null   int64
#  8   Device Usage                     1000 non-null   object
#  9   Time Spent Online (hrs/weekday)  1000 non-null   float64
#  10  Time Spent Online (hrs/weekend)  1000 non-null   float64
#  11  Click-Through Rates (CTR)        1000 non-null   float64
# ...

# %%
data.isnull().sum()
# Out:
# User ID                            0
# Age                                0
# Gender                             0
# Location                           0
# Language                           0
# Education Level                    0
# Likes and Reactions                0
# Followed Accounts                  0
# Device Usage                       0
# Time Spent Online (hrs/weekday)    0
# Time Spent Online (hrs/weekend)    0
# Click-Through Rates (CTR)          0
# Conversion Rates                   0
# Ad Interaction Time (sec)          0
# Income Level                       0
# Top Interests                      0
# dtype: int64

# %%
data.describe()
# Out:
#            User ID  Likes and Reactions  Followed Accounts  \
# count  1000.000000          1000.000000        1000.000000
# mean    500.500000          4997.084000         251.438000
# std     288.819436          2838.494365         141.941557
# min       1.000000           101.000000          10.000000
# 25%     250.750000          2661.250000         126.000000
# 50%     500.500000          5002.500000         245.500000
# 75%     750.250000          7348.750000         377.000000
# max    1000.000000          9973.000000         498.000000
#
#        Time Spent Online (hrs/weekday)  Time Spent Online (hrs/weekend)  \
# count                      1000.000000                      1000.000000
# mean                          2.757500                         4.601600
# std                           1.279735                         2.026234
# min                           0.500000                         1.000000
# ...

# %% [markdown]
# #### Q.2: Begin EDA by visualizing the distribution of the key demographic variables (age, gender,education level, and income level)

# %%
import matplotlib.pyplot as plt

# %%
fig, axes=plt.subplots(2,2,figsize=(18,15))
fig.suptitle("Distribution of Key Demographics Variables")

# Age Distribution
axes[0,0].hist(data['Age'], color='blue')
axes[0,0].set_title('Age Distribution')
axes[0,0].set_xlabel('Age')
axes[0,0].set_ylabel('count')
axes[0,0].yaxis.grid(True)

# Gender Distribution
axes[0,1].hist(data['Gender'], color='purple')
axes[0,1].set_title('Gender Distribution')
axes[0,1].set_xlabel('Gender')
axes[0,1].set_ylabel('count')
axes[0,1].yaxis.grid(True)

# Education level Distribution
axes[1,0].hist(data['Education Level'], color='pink')
axes[1,0].set_title('Education level Distribution')
axes[1,0].set_xlabel('Education')
axes[1,0].set_ylabel('count')
axes[1,0].yaxis.grid(True)

# Income level Distribution
axes[1,1].hist(data['Income Level'], color='green')
axes[1,1].set_title('Income level Distribution')
axes[1,1].set_xlabel('Income')
axes[1,1].set_ylabel('count')
axes[1,1].yaxis.grid(True)

# %% [markdown]
# #### Q.3: Now examine device usage patterns to understand the primary means by which users access the platform. Additionally, explore users’ online behaviour, including their engagement with content and ads, and identify the most common interests among users.

# %%
data['Device Usage'].hist(color='purple')
plt.title("Device Usage distribution")
plt.xlabel('Device Usage')
plt.ylabel('count')
plt.grid(False)
plt.show()

# %% [markdown]
# #### Q.4:
# Analyze the average time users spend online on weekdays versus weekends
# Investigate user engagement metrics, such as likes and reaction .
# Delve into ad interaction metrics, including Click-Through Rates (CTR), Conversion Rats,
# and Ad Interaction Tme.
# It will help to understand the users’ activity patterns and their interaction with ads, whih is
# crucial for effective ad targeting and optimization.

# %%
import matplotlib.pyplot as plt

# Define the figure and axes
fig, axes = plt.subplots(3, 2, figsize=(18, 15))
fig.suptitle('User Online Behavior and Ad Interaction Metrics')

# Time spent online on weekdays
axes[0, 0].hist(data['Time Spent Online (hrs/weekday)'], bins=20, color='skyblue', edgecolor='white')
axes[0, 0].set_title('Time Spent Online on Weekdays')
axes[0, 0].set_xlabel('Time Spent Online (hrs)')
axes[0, 0].set_ylabel('Frequency')

# Time spent online on weekends
axes[0, 1].hist(data['Time Spent Online (hrs/weekend)'], bins=20, color='yellow', edgecolor='white')
axes[0, 1].set_title('Time Spent Online on Weekends')
axes[0, 1].set_xlabel('Time Spent Online (hrs)')
axes[0, 1].set_ylabel('Frequency')

# Likes and reactions
axes[1, 0].hist(data['Likes and Reactions'], bins=20, color='green', edgecolor='white')
axes[1, 0].set_title('Likes and Reactions')
axes[1, 0].set_xlabel('Likes and Reactions')
axes[1, 0].set_ylabel('Frequency')

# Click-through rates
axes[1, 1].hist(data['Click-Through Rates (CTR)'], bins=20, color='pink', edgecolor='white')
axes[1, 1].set_title('Click-Through Rates (CTR)')
axes[1, 1].set_xlabel('Click-Through Rates (CTR)')
axes[1, 1].set_ylabel('Frequency')

# Conversion rates
axes[2, 0].hist(data['Conversion Rates'], bins=20, color='purple', edgecolor='white')
axes[2, 0].set_title('Conversion Rates')
axes[2, 0].set_xlabel('Conversion Rates')
axes[2, 0].set_ylabel('Frequency')

# Ad interaction time
axes[2, 1].hist(data['Ad Interaction Time (sec)'], bins=20, color='brown', edgecolor='white')
axes[2, 1].set_title('Ad Interaction Time (sec)')
axes[2, 1].set_xlabel('Ad Interaction Time (sec)')
axes[2, 1].set_ylabel('Frequency')

# Adjust layout and display the plot
plt.tight_layout(rect=[0, 0.03, 1, 0.95])
plt.show()

# %% [markdown]
# #### Q.5: Identify the most common interests among users, which is vital for segmenting the audience and tailoring ad campaigns to match user preferences

# %%
import matplotlib.pyplot as plt
import matplotlib.pyplot as plt

# Splitting the 'Top Interests' column and creating a list of all interests
interests_list = data['Top Interests'].str.split(', ').explode()
# Counting the frequency of each interest
# head(10)=> Selects only the first 10 entries from the result, which are the 10 most frequent interests.
top_interests = interests_list.value_counts().head(10)

plt.figure(figsize=(12, 8))
top_interests.plot(kind='barh', color='skyblue')
plt.title('Top User Interests')
plt.xlabel('Frequency')
plt.ylabel('Interest')
plt.gca().invert_yaxis()  # Invert y-axis to have the highest frequency at the top
plt.show()

# %% [markdown]
# #### Q.6: You can now segment users into distinct groups for targeted ad campaigns. Segmentation
# can be based on various criteria, such a
# Demographics: Age, Gender, Income Level, Education Lev .l
# Behavioural: Time Spent Online, Likes and Reactions, CTR, Conversion Ra. es
# Interests: Aligning ad content with the top interests identi. ied
# To implement user profiling and segmentation, apply clustering techniques or de elop
# personas based on the combination of these attri utes.
# Start by selecting a subset of features that could be most indicative of user preferen es and
# behaviour for segmentation and apply a clustering algorithm to create user segments:

# %%
from sklearn.preprocessing import StandardScaler, OneHotEncoder
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline
from sklearn.cluster import KMeans

# selecting features for clustering
features = ['Age', 'Gender', 'Income Level', 'Time Spent Online (hrs/weekday)', 'Time Spent Online (hrs/weekend)', 'Likes and Reactions', 'Click-Through Rates (CTR)']

# separating the features we want to consider for clustering
X = data[features]

# defining preprocessing for numerical and categorical features
numeric_features = ['Time Spent Online (hrs/weekday)', 'Time Spent Online (hrs/weekend)', 'Likes and Reactions', 'Click-Through Rates (CTR)']
numeric_transformer = StandardScaler()

categorical_features = ['Age', 'Gender', 'Income Level']
categorical_transformer = OneHotEncoder()

# combining preprocessing steps
preprocessor = ColumnTransformer(
    transformers=[
        ('num', numeric_transformer, numeric_features),
        ('cat', categorical_transformer, categorical_features)
    ])

# creating a preprocessing and clustering pipeline
pipeline = Pipeline(steps=[('preprocessor', preprocessor),
                           ('cluster', KMeans(n_clusters=5, random_state=42))])

pipeline.fit(X)
cluster_labels = pipeline.named_steps['cluster'].labels_
data['Cluster'] = cluster_labels

print(data.head())
# Out:
#    User ID    Age  Gender  Location Language Education Level  \
# 0        1  25-34  Female  Suburban    Hindi       Technical
# 1        2    65+    Male     Urban    Hindi             PhD
# 2        3  45-54  Female  Suburban  Spanish       Technical
# 3        4  35-44  Female     Rural  Spanish             PhD
# 4        5  25-34  Female     Urban  English       Technical
#
#    Likes and Reactions  Followed Accounts  Device Usage  \
# 0                 5640                190   Mobile Only
# 1                 9501                375        Tablet
# 2                 4775                187   Mobile Only
# 3                 9182                152  Desktop Only
# 4                 6848                371   Mobile Only
#
#    Time Spent Online (hrs/weekday)  Time Spent Online (hrs/weekend)  \
# 0                              4.5                              1.7
# 1                              0.5                              7.7
# ...

# %% [markdown]
# #### Q.7: Now compute the mean values of the numerical features and the mode for categorical
# features within each cluster to get a sense of their      defining characteristics

# %%
cluster_means = data.groupby('Cluster')[numeric_features].mean()

for feature in categorical_features:
    mode_series = data.groupby('Cluster')[feature].agg(lambda x: x.mode()[0])
    cluster_means[feature] = mode_series

print(cluster_means)
# Out:
#          Time Spent Online (hrs/weekday)  Time Spent Online (hrs/weekend)  \
# Cluster
# 0                               3.911111                         5.212963
# 1                               1.559394                         6.002424
# 2                               3.019737                         2.584211
# 3                               3.080882                         5.774510
# 4                               1.809626                         3.839572
#
#          Likes and Reactions  Click-Through Rates (CTR)    Age  Gender  \
# Cluster
# 0                2409.620370                   0.149588  25-34  Female
# 1                5005.121212                   0.179836  35-44    Male
# 2                6861.587719                   0.170614  25-34    Male
# 3                7457.602941                   0.067971  25-34  Female
# 4                3021.219251                   0.056594  45-54  Female
#
#         Income Level
# Cluster
# 0           80k-100k
# ...
